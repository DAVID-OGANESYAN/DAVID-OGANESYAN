# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

file_path = 'WorldHappiness.xls'
data = pd.read_excel(file_path).dropna()

# %%
european_countries = ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium',
    'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic',
    'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece',
    'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kosovo', 'Latvia',
    'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova',
    'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway',
    'Poland', 'Portugal', 'Romania', 'San Marino', 'Serbia', 'Slovakia',
    'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine',
    'United Kingdom', 'Vatican City']

# %%
def find_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

variables = ['Life Ladder', 'Log GDP per capita', 'Social support', 
    'Healthy life expectancy at birth', 'Freedom to make life choices', 
    'Generosity', 'Perceptions of corruption', 'Positive affect', 'Negative affect']

outliers_list = []

#finding outliers
for column in variables:
    outliers = find_outliers(european_countries_data, column)
    if not outliers.empty:
        for index, row in outliers.iterrows():
            outliers_list.append({'Country': row['Country name'],'Column': column,'Value': row[column]})

outliers_df = pd.DataFrame(outliers_list)
print(outliers_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      16 #finding outliers
#      17 for column in variables:
# ---> 18     outliers = find_outliers(european_data, column)
#      19     if not outliers.empty:
#      20         for index, row in outliers.iterrows():
#
# NameError: name 'european_data' is not defined

# %%
#scatter plot
for column in variables:
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=european_data, x='Country name', y=column)
    outliers = find_outliers(european_data, column)
    sns.scatterplot(data=outliers, x='Country name', y=column, color='red', s=100)
    plt.xticks(rotation=90)
    plt.title(f'Scatter plot for {column} in European Countries with Outliers')
    plt.xlabel('Country name')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ### Overview of European outliers
# ---
# -  **Life Ladder**:
#
#    Life satisfaction scores are quite consistent across most European countries, with no major outliers.
#
# -  **Log GDP per Capita**:
#
#    Economic conditions are generally stable, but countries like Luxembourg and Norway have significantly higher GDP per capita.
#
# -  **Social Support**:
#
#    Social support is robust across Europe, especially in Scandinavian countries, with only a few minor outliers.
#
# -  **Healthy Life Expectancy at Birth**:
#
#    Life expectancy varies widely, reflecting different health conditions. Western European countries generally enjoy higher life expectancies.
#
# -  **Freedom to Make Life Choices**:
#
#    Most Europeans feel a high degree of freedom in making life choices, with few exceptions.
#
# -  **Generosity**:
#
#    Generosity levels are fairly uniform, but countries such as Ireland and the United Kingdom show higher rates.
#
# -  **Positive Affect**:
#
#    Positive emotions are consistent across Europe, with Western European countries exhibiting higher levels.
#
# -  **Perceptions of Corruption**:
#
#    There is a significant variation in how corruption is perceived, with Scandinavian countries generally reporting lower levels.
#
# -  **Negative Affect**:
#
#    It can be observed, that some Eastern European countries report higher levels of negative emotions.
#
# ---
#    **Overall, these indicators provide a comprehensive picture of well-being and quality of life in Europe**
